# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns


df=pd.read_csv("SampleSuperstore.csv")

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
#Insights of the data
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#Checking the null values in the  dataset
df.isna().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#Checking the data type of the different features
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.rename(columns = {'Ship Mode':'Ship_Mode'}, inplace = True)

# %%
# For insights of the coloumn
df.Ship_Mode.value_counts(normalize=False, sort=True, ascending=False, bins=None, dropna=True)
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship_Mode, dtype: int64

# %% [markdown]
# # Visualization of the data set

# %%
sns.pairplot(df)
plt.show()

# %%
# %matplotlib inline
sns.set(style="darkgrid")
ax = sns.countplot(df['Ship_Mode'],data=df, palette ='prism')
plt.title('Ship_Mode',fontsize=30)
# Out:
# Text(0.5, 1.0, 'Ship_Mode')

# %%
# %matplotlib inline
sns.set(style="darkgrid")
ax = sns.countplot(df['Segment'],data=df, palette ='dark')
plt.title('Segment',fontsize=30)
# Out:
# Text(0.5, 1.0, 'Segment')

# %%
# %matplotlib inline
sns.set(style="darkgrid")

ax = sns.countplot(df['Region'],data=df, palette ='coolwarm')
plt.title('Region',fontsize=30)
# Out:
# Text(0.5, 1.0, 'Region')

# %%
fig = plt.figure(figsize=(15,5))
plt.title("Comparision of various features with Sales",fontsize=30)


fig.add_subplot(131)
sns.barplot(x="Quantity",y="Sales",data=df)


fig.add_subplot(132)
sns.barplot(x="Discount",y="Sales",data=df)


fig.add_subplot(133)
sns.barplot(x="Region",y="Sales",data=df)

# %%
fig = plt.figure(figsize=(35,13))
plt.title("Comparing different depedency on the features",fontsize=60)


fig.add_subplot(131)
sns.barplot(x="Ship_Mode",y="Sales",hue='Discount',data=df,palette='dark')

fig.add_subplot(132)
sns.barplot(x="Sales",y="Region",hue='Quantity',data=df,palette='coolwarm')

fig.add_subplot(133)
sns.barplot(x="Sales",y="Category",hue='Segment',data=df,palette='Set1')

# %%
df.columns
# Out:
# Index(['Ship_Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
sns.set(rc={'figure.figsize':(8,8)})
df.hist()
plt.show()

# %%
# For each numeric attribute of dataframe 
df.plot.box() 
sns.set(rc={'figure.figsize':(5,11)})
plt.title("Visualizing the annomalities,Mean & Median",fontsize=20)

# individual attribute box plot 
plt.boxplot(df['Sales']) 
plt.show() 
#since the values were same every time so i have not added indivisualy each

# %%
sns.set(rc={'figure.figsize':(10,10)})
plt.title("Scatter plot Between Quantity & Sales ",fontsize=30)

plt.scatter(df['Quantity'],df['Sales']) 
plt.show()

# %%
sns.set(rc={'figure.figsize':(10,10)})
plt.title("Scatter plot Between Discount & Sales ",fontsize=30)


plt.scatter(df['Discount'],df['Sales']) 
plt.show()

# %%
df.columns
# Out:
# Index(['Ship_Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# # Pie Chart with different data inputs

# %%
fig = plt.figure(figsize=(30,10))
plt.subplots_adjust(left=0.125,right=0.9,top=0.9,hspace=0.1,wspace=0.1)
plt.title("Comparison between Various data input",fontsize=30)


fig.add_subplot(151)
plt.title("Ship_Mode",fontsize=30)
df['Ship_Mode'].value_counts().plot.pie(autopct ='% 1.1f %%', shadow = True) 

fig.add_subplot(152)
plt.title("Segment",fontsize=30)
df['Segment'].value_counts().plot.pie(autopct ='% 1.1f %%', shadow = True) 

fig.add_subplot(153)
plt.title("Category",fontsize=30)
df['Category'].value_counts().plot.pie(autopct ='% 1.1f %%', shadow = True) 

fig.add_subplot(154)
plt.title("Region",fontsize=30)
df['Region'].value_counts().plot.pie(autopct ='% 1.1f %%', shadow = True) 

fig.add_subplot(155)
plt.title("City",fontsize=30)
df['City'].value_counts().plot.pie(autopct ='% 1.1f %%', shadow = True) 
plt.show()

# %%
sns.set(rc={'figure.figsize':(5,5)})

plt.scatter(range(df.shape[0]), np.sort(df['Quantity'].values))
plt.xlabel('Value')
plt.ylabel('Quantity')
plt.title("Maths marks distribution")
sns.despine()

# %%
da=pd.crosstab(df['Discount'],df['Category'])
da.plot.bar(stacked=True)
plt.show()

# %% [markdown]
# # Creating a new Columns

# %%
profit=[]

#For more relevant data analysis

def result(prof):
    for i in prof:
        if i>=200:
            profit.append('Huge Profit')
        elif i>=50.0 and i<200.0:
            profit.append('Profit')
        elif i>=0.0 and i<50.0:
            profit.append('Margin')
        elif i<0and i>=50.0:
            profit.append('loss')
        else:
            profit.append('Huge Loss')
    return profit

# %%
result(df.Profit)
# Out:
# ['Margin',
#  'Huge Profit',
#  'Margin',
#  'Huge Loss',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Profit',
#  'Margin',
#  'Margin',
#  'Profit',
#  'Profit',
#  'Margin',
#  'Profit',
#  'Huge Loss',
#  'Huge Loss',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Huge Loss',
#  'Huge Profit',
#  'Margin',
#  'Margin',
#  'Huge Loss',
#  'Huge Loss',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Huge Loss',
#  'Margin',
#  'Margin',
#  'Profit',
#  'Huge Loss',
#  'Margin',
#  'Huge Loss',
#  'Huge Loss',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Huge Profit',
#  'Profit',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Profit',
#  'Margin',
#  'Huge Loss',
#  'Profit',
#  'Profit',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Huge Loss',
# ...

# %%
profit
# Out:
# ['Margin',
#  'Huge Profit',
#  'Margin',
#  'Huge Loss',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Profit',
#  'Margin',
#  'Margin',
#  'Profit',
#  'Profit',
#  'Margin',
#  'Profit',
#  'Huge Loss',
#  'Huge Loss',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Huge Loss',
#  'Huge Profit',
#  'Margin',
#  'Margin',
#  'Huge Loss',
#  'Huge Loss',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Huge Loss',
#  'Margin',
#  'Margin',
#  'Profit',
#  'Huge Loss',
#  'Margin',
#  'Huge Loss',
#  'Huge Loss',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Huge Profit',
#  'Profit',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Profit',
#  'Margin',
#  'Huge Loss',
#  'Profit',
#  'Profit',
#  'Margin',
#  'Margin',
#  'Margin',
#  'Huge Loss',
# ...

# %%
df['Overall']=profit

# %%
plt.title("Region",fontsize=30)
df['Overall'].value_counts().plot.pie(autopct ='% 1.1f %%', shadow = True)

# %%
sns.barplot(x="Ship_Mode",y="Sales",hue='Overall',data=df,palette='dark')
